# %%
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (11, 5)

# %% [markdown]
# `Создадим функцию для вычисления исходной функции, изобразим ее график.`

# %%
def f(x):
    return np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)
f = np.vectorize(f)

# %%
xs = np.arange(0, 15, 0.1)

# %%
plt.plot(xs, f(xs), label="initial function f(x)")
plt.legend()

# %% [markdown]
# `Попробуем приблизить функцию f полиномом первого порядка. Коэффициенты полинома подберем, решив систему уравнений при условии, что полином проходит через точки (1, f(1)) и (15, f(15)).`

# %%
A_1 = np.array([[1, 1], [1, 15]])
b_1 = np.array([float(f(1)), float(f(15))])

# %%
w_1 = sp.linalg.solve(A_1, b_1)
w_1
# Out:
# array([ 1.94326263, -0.10386542])

# %%
len(w_1)
# Out:
# 2

# %%
def polynom(x, w=None):
    n = len(w)
    f = sum([w[i] * (x ** i) for i in xrange(n)])
    return f
polynom = np.vectorize(polynom, excluded=['w'])

# %%
polynom(2, w_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-ce611da49d06> in <module>()
# ----> 1 polynom(2, w_1)
#
# /home/lysuhin/Distr/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in __call__(self, *args, **kwargs)
#    2216             vargs.extend([kwargs[_n] for _n in names])
#    2217
# -> 2218         return self._vectorize_call(func=func, args=vargs)
#    2219
#    2220     def _get_ufunc_and_otypes(self, func, args):
#
# /home/lysuhin/Distr/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in _vectorize_call(self, func, args)
#    2279             _res = func()
#    2280         else:
# -> 2281             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2282
#    2283             # Convert args to object arrays first
#
# ...
